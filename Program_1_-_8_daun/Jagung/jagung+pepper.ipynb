# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
import os
import cv2
from sklearn.model_selection import train_test_split
from tqdm import tqdm  # import tqdm for progress bar 
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
target_labels = ['Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Corn_(maize)___Common_rust_', 'Corn_(maize)___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy']

# %%
main_path = 'data_penyakit/dataset/train'

# %%
# Load the images and labels
filename = []
X = []
y = []
for label in target_labels:
    label_dir = os.path.join(main_path, label)
    for img_file in os.listdir(label_dir):
        img_path = os.path.join(label_dir, img_file)
        img = load_img(img_path, target_size=(128, 128))
        img_array = img_to_array(img)
        filename.append(img_file)
        X.append(img_array)
        y.append(target_labels.index(label))

# %%
from tensorflow.keras.utils import to_categorical

# %%
X = np.array(X)
y = to_categorical(y, num_classes=len(target_labels))

# %%
X.shape
# Out:
# (11217, 128, 128, 3)

# %%
y.shape
# Out:
# (11217, 6)

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test, filename_train, filename_test = train_test_split(X, y, filename, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (8973, 128, 128, 3)

# %%
X_test.shape
# Out:
# (2244, 128, 128, 3)

# %%
y_train.shape
# Out:
# (8973, 6)

# %%
y_test.shape
# Out:
# (2244, 6)

# %%
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.models import Sequential

# %%
len(target_labels)
# Out:
# 6

# %%
cnn_model = Sequential()
cnn_model.add(Conv2D(32, kernel_size= (3,3), activation = 'relu',input_shape=(128,128,3)))
cnn_model.add(MaxPooling2D(pool_size =(2,2,)))
cnn_model.add(BatchNormalization())
cnn_model.add(Conv2D(64,kernel_size= (3,3), activation = 'relu'))
cnn_model.add(MaxPooling2D(pool_size =(2,2,)))
cnn_model.add(BatchNormalization())
cnn_model.add(Conv2D(64,kernel_size= (3,3), activation = 'relu'))
cnn_model.add(MaxPooling2D(pool_size =(2,2,)))
cnn_model.add(BatchNormalization())
cnn_model.add(Conv2D(96,kernel_size= (3,3), activation = 'relu'))
cnn_model.add(MaxPooling2D(pool_size =(2,2,)))
cnn_model.add(BatchNormalization())
cnn_model.add(Conv2D(32,kernel_size= (3,3), activation = 'relu'))
cnn_model.add(MaxPooling2D(pool_size =(2,2,)))
cnn_model.add(BatchNormalization())

cnn_model.add(Dropout(0.2))
cnn_model.add(Flatten())
cnn_model.add(Dense(128, activation = 'relu'))
cnn_model.add(Dropout(0.3))
cnn_model.add(Dense(len(target_labels), activation='softmax'))
cnn_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the CNN model
cnn_history = cnn_model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 2023-05-31 16:01:25.997712: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 281/281 [==============================] - 51s 178ms/step - loss: 0.4228 - accuracy: 0.8433 - val_loss: 0.5544 - val_accuracy: 0.7981
# Epoch 2/10
# 281/281 [==============================] - 51s 181ms/step - loss: 0.1752 - accuracy: 0.9359 - val_loss: 0.3295 - val_accuracy: 0.8881
# Epoch 3/10
# 281/281 [==============================] - 54s 191ms/step - loss: 0.1238 - accuracy: 0.9546 - val_loss: 0.1223 - val_accuracy: 0.9599
# Epoch 4/10
# 281/281 [==============================] - 69s 246ms/step - loss: 0.1129 - accuracy: 0.9601 - val_loss: 0.3763 - val_accuracy: 0.8788
# Epoch 5/10
# 281/281 [==============================] - 107s 381ms/step - loss: 0.0939 - accuracy: 0.9676 - val_loss: 0.1438 - val_accuracy: 0.9514
# Epoch 6/10
# 281/281 [==============================] - 127s 452ms/step - loss: 0.0844 - accuracy: 0.9704 - val_loss: 0.1618 - val_accuracy: 0.9296
# Epoch 7/10
# 281/281 [==============================] - 126s 449ms/step - loss: 0.0697 - accuracy: 0.9751 - val_loss: 0.4373 - val_accuracy: 0.8414
# Epoch 8/10
# 281/281 [==============================] - 126s 448ms/step - loss: 0.0764 - accuracy: 0.9718 - val_loss: 0.0758 - val_accuracy: 0.9710
# Epoch 9/10
# 281/281 [==============================] - 129s 458ms/step - loss: 0.0662 - accuracy: 0.9759 - val_loss: 0.1263 - val_accuracy: 0.9545
# Epoch 10/10
# 281/281 [==============================] - 121s 429ms/step - loss: 0.0515 - accuracy: 0.9823 - val_loss: 0.1154 - val_accuracy: 0.9643

# %%
# Evaluate the performance of the trained CNN model on the test set
cnn_scores = cnn_model.evaluate(X_test, y_test, verbose=0)
print("CNN Model Accuracy: %.2f%%" % (cnn_scores[1] * 100))
# Out:
# CNN Model Accuracy: 96.43%

# %%
cnn_scores
# Out:
# [0.11541353911161423, 0.9643493890762329]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Use the model to predict the test dataset
y_pred_prob = cnn_model.predict(X_test)

# Convert probabilities to classes
y_pred = np.argmax(y_pred_prob, axis=1)

# If y_test is one-hot encoded, convert it to classes as well
y_test_classes = np.argmax(y_test, axis=1)

# Calculate accuracy
accuracy = accuracy_score(y_test_classes, y_pred)

# Calculate precision
precision = precision_score(y_test_classes, y_pred, average='weighted') 

# Calculate recall
recall = recall_score(y_test_classes, y_pred, average='weighted') 

# Calculate F1 score
f1 = f1_score(y_test_classes, y_pred, average='weighted')

# Print the metrics
print("Accuracy: %.2f%%" % (accuracy * 100))
print("Precision: %.2f%%" % (precision * 100))
print("Recall: %.2f%%" % (recall * 100))
print("F1 score: %.2f%%" % (f1 * 100))
# Out:
# 71/71 [==============================] - 8s 106ms/step
# Accuracy: 96.43%
# Precision: 96.49%
# Recall: 96.43%
# F1 score: 96.43%

# %%
from tabulate import tabulate

# Create a DataFrame with true labels, predicted labels, and target labels
df = pd.DataFrame({'Filename': filename_test,
                   'True Labels': [target_labels[label] for label in y_test_classes],
                   'Predicted Labels': [target_labels[label] for label in y_pred]})

# Convert DataFrame to tabular format
table = tabulate(df, headers='keys', tablefmt='psql')

# Print the table
print(table)

# Save the DataFrame to a CSV file
df.to_csv('labels_predictions-cnn-jagung+pepper.csv', index=False)
# Out:
# +------+-------------------------------------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# |      | Filename                                                                      | True Labels                                        | Predicted Labels                                   |
# |------+-------------------------------------------------------------------------------+----------------------------------------------------+----------------------------------------------------|
# |    0 | 98327d43-c692-4922-82e3-a4e0db73ae40___JR_HL 8483.JPG                         | Pepper,_bell___healthy                             | Pepper,_bell___healthy                             |
# |    1 | RS_Rust 2762.JPG                                                              | Corn_(maize)___Common_rust_                        | Corn_(maize)___Common_rust_                        |
# |    2 | 348aafc3-4309-4507-b6b3-cb037711ca48___RS_GLSp 4399_90deg.JPG                 | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# |    3 | bd2ca97a-465c-4f10-a561-8b0cbdb77db3___JR_HL 8897.JPG                         | Pepper,_bell___healthy                             | Pepper,_bell___healthy                             |
# |    4 | 852e8e42-c48b-4a49-9f06-cae0ecb7747e___R.S_HL 8271 copy.jpg                   | Corn_(maize)___healthy                             | Corn_(maize)___healthy                             |
# |    5 | 7f07dc8d-dc42-4b4a-89a8-f2d2e10bdba7___NREC_B.Spot 9167.JPG                   | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___Bacterial_spot                      |
# |    6 | d95f6c9c-1c62-47d6-a643-093cd3402162___RS_NLB 3942 copy 2_flipTB.jpg          | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Northern_Leaf_Blight                |
#
JPG                       | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# +------+-------------------------------------------------------------------------------+----------------------------------------------------+----------------------------------------------------+

# %%
# Filter rows where true label and predicted label do not match
false_predictions = df[df['True Labels'] != df['Predicted Labels']]

# Convert DataFrame to tabular format
table = tabulate(false_predictions, headers='keys', tablefmt='psql')

# Print the false predictions table
print("False Predictions:")
print(table)

# Save the false predictions to a CSV file
false_predictions.to_csv('false_predictions-cnn-jagung+pepper.csv', index=False)
# Out:
# False Predictions:
# +------+------------------------------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# |      | Filename                                                               | True Labels                                        | Predicted Labels                                   |
# |------+------------------------------------------------------------------------+----------------------------------------------------+----------------------------------------------------|
# |   60 | f176a365-b5f0-4b3f-a4bc-d4d2c705b29e___JR_B.Spot 3263_flipTB.JPG       | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# |   78 | 2a42396f-f9a9-47cc-9dd7-7149faf1e0e2___JR_HL 8544_newPixel25.JPG       | Pepper,_bell___healthy                             | Corn_(maize)___healthy                             |
# |   93 | a401fce7-28ad-4d2f-bf98-3ef87ae65ba5___RS_GLSp 4614.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  120 | 57d9d6f1-8f81-4b5b-8985-c82b136a6c4c___JR_B.Spot 8846_flipTB.JPG       | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# |  202 | bbea95f8-cc26-40b6-9436-228f70d605d7___RS_GLSp 7332.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  210 | f5eb9c66-7174-4f62-8261-7c7520601824___RS_GLSp 9342.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Common_rust_                        |
# |  259 | 241fe005-f805-4e76-bf80-e7a84aa0b9a8___RS_GLSp 9336_90deg.JPG          | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Pepper,_bell___Bacterial_spot                      |
# |  271 | 56a3748f-881d-4adb-ab0a-85b5cc6883a9___NREC_B.Spot 9180_180deg.JPG     | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# |  279 | 6728afe3-9ab4-4235-b7e3-5b9ee80b6675___RS_NLB 3605_flipTB.JPG          | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# |  281 | 629273b6-9eaa-4084-b72b-ac856a9ef899___RS_GLSp 4636_270deg.JPG         | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  291 | 34ae03ee-4314-47b1-a568-f3537bc2afba___RS_NLB 3672_180deg.JPG          | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# |  301 | 74967cb3-e984-43f3-9bd3-74ba302b1db7___RS_GLSp 4555.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  305 | bbde9366-ec3c-4354-815b-5b95b6cdb676___RS_GLSp 4481.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  320 | 1157b4eb-dfb3-41b7-a083-77b0ca2e7634___RS_GLSp 4460.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  325 | f5773153-728e-4631-8cc8-1bc06412df89___RS_NLB 4056.JPG                 | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# |  343 | 4040f0a8-b1e5-47e9-b8ad-521818bf8c52___NREC_B.Spot 9202.JPG            | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# |  354 | b3f86927-5a59-4e12-a6c5-06e82d45388d___NREC_B.Spot 9234.JPG            | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# |  395 | b2980d13-da6a-4475-bb60-abed664c5506___RS_GLSp 4678.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  431 | baf87bb4-cf33-432d-ae8c-6ee3bd6dacce___JR_B.Spot 8988_flipTB.JPG       | Pepper,_bell___Bacterial_spot                      | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# |  456 | cec0354e-5caf-4eb7-9fa5-a7b07ac1b644___JR_B.Spot 9070_flipTB.JPG       | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# |  557 | RS_Rust 2190_flipLR.JPG                                                | Corn_(maize)___Common_rust_                        | Pepper,_bell___healthy                             |
# |  560 | 0d4e35c0-f6d6-4810-9522-14e1d491a05d___JR_HL 8673_180deg.JPG           | Pepper,_bell___healthy                             | Corn_(maize)___healthy                             |
# |  577 | 6089948d-346f-4745-af12-4355a7ef3dea___RS_NLB 3800_flipTB.JPG          | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# |  581 | 6f129430-750d-4d02-b509-1ec760ae8aaa___RS_NLB 3486 copy.jpg            | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___healthy                             |
# |  605 | ba462265-a5c8-4fa8-abb4-24054691eb16___RS_GLSp 3809.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  623 | 7972395e-d2f0-4cf8-a4b5-ac4ca91d4a6e___JR_B.Spot 9075_180deg.JPG       | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# |  694 | 910679a5-f18d-40ac-a00e-9e2c27a45610___RS_GLSp 9327.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  726 | 2a510a2e-0e15-4ee3-9a66-a7bc27710c91___JR_HL 7704_newPixel25.JPG       | Pepper,_bell___healthy                             | Corn_(maize)___healthy                             |
# |  763 | e5d4ffee-90c7-4a04-8fa8-61e496dfefc3___RS_GLSp 4367.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  825 | 03a4f6f6-9c17-4310-921b-5dbf97df630a___JR_HL 8571_newPixel25.JPG       | Pepper,_bell___healthy                             | Corn_(maize)___healthy                             |
# |  863 | 4baea4d9-8343-4550-838f-86dfb7672591___RS_GLSp 4639 copy.jpg           | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  970 | e90ac690-4fbd-4ded-94f2-af7373479164___JR_B.Spot 8931_flipTB.JPG       | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# |  971 | e20d6d7c-2508-4a75-9143-5c49d0c02d12___RS_NLB 3604 copy_flipTB.jpg     | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 1007 | 3dbd080a-21d0-4fb0-8c31-9638c6030943___JR_HL 5817_newPixel25.JPG       | Pepper,_bell___healthy                             | Corn_(maize)___healthy                             |
# | 1018 | e22976d4-ff48-4672-ad70-e17d50b65b1c___RS_NLB 3688_180deg.JPG          | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 1024 | 057c3f91-c15e-464b-b4ba-66b16dbe5149___RS_NLB 3565 copy.jpg            | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 1083 | 44209d86-9fed-42cd-b5dc-5580166b10ab___RS_GLSp 4684.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 1095 | d598dca9-3560-44d7-ac84-7dc1eeb72655___NREC_B.Spot 9121.JPG            | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# | 1155 | d2a1f0d8-2835-4984-80fd-11be9e18ab22___RS_GLSp 4580.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 1195 | d3d7a5a3-ee3f-4654-8e90-8e722d433972___RS_NLB 3553_180deg.JPG          | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Common_rust_                        |
# | 1203 | 57d9d6f1-8f81-4b5b-8985-c82b136a6c4c___JR_B.Spot 8846.JPG              | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# | 1270 | 573ad2a6-906a-4d32-af81-0026fc57258f___RS_GLSp 4613.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 1289 | 0995786c-d397-439a-bfeb-bd897cd431c8___RS_GLSp 9343_90deg.JPG          | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___healthy                             |
# | 1291 | 50a8d45e-07fa-495d-8779-e07715b1c644___RS_GLSp 9358.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Common_rust_                        |
# | 1374 | e8527ec9-d83a-49c6-b0ed-1833e6350e23___RS_NLB 3796_flipTB.JPG          | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 1388 | 2aca721c-1600-4f8c-8e79-df33973c671c___RS_GLSp 9348_new30degFlipLR.JPG | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Pepper,_bell___healthy                             |
# | 1424 | 66078e98-f5db-446d-8d34-f6268d8703e0___JR_B.Spot 3285_180deg.JPG       | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# | 1439 | 4995d36f-321f-4f9e-82c8-9a0c78d1f266___NREC_B.Spot 9076.JPG            | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# | 1440 | 3e71a4e5-32e9-404e-815c-95208f7a79fd___JR_B.Spot 3258.JPG              | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# | 1442 | 302d1d00-fe10-4ec1-878c-5ac721c6ec44___RS_GLSp 9356_90deg.JPG          | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___healthy                             |
# | 1446 | 88a00319-c477-422b-bc43-91d03382f8c7___JR_B.Spot 3402_180deg.JPG       | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# | 1483 | d598dca9-3560-44d7-ac84-7dc1eeb72655___NREC_B.Spot 9121_flipTB.JPG     | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# | 1491 | RS_Rust 2683_flipLR.JPG                                                | Corn_(maize)___Common_rust_                        | Pepper,_bell___healthy                             |
# | 1548 | RS_Rust 1680_flipLR.JPG                                                | Corn_(maize)___Common_rust_                        | Pepper,_bell___Bacterial_spot                      |
# | 1555 | 2e594c45-c4c7-43b1-ab19-100945e7a2a7___RS_NLB 4020 copy 3.jpg          | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___healthy                             |
# | 1556 | cb647989-23e4-4d54-ba50-7685b19e780d___RS_GLSp 9280_90deg.JPG          | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___healthy                             |
# | 1626 | f69b1b10-dd7f-44c0-b084-1959316e4f2a___RS_NLB 3955 copy 2_180deg.jpg   | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 1631 | 9728896c-149f-415b-86b3-ef5b95dd9143___JR_B.Spot 8862.JPG              | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# | 1638 | 15803dee-8071-49f1-81b6-fd3dedbc1c58___RS_NLB 4020 copy.jpg            | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 1639 | 5dc9613c-fcbf-42ce-a95a-6520bf780872___RS_NLB 4225.JPG                 | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 1647 | f176a365-b5f0-4b3f-a4bc-d4d2c705b29e___JR_B.Spot 3263.JPG              | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# | 1664 | 3da82d3f-34cf-4e0f-9ed4-1a77526dddb4___JR_HL 8611_newPixel25.JPG       | Pepper,_bell___healthy                             | Corn_(maize)___healthy                             |
# | 1712 | ffa3b1df-49c6-4fd2-9ec5-1ca5eb175797___JR_B.Spot 3254.JPG              | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# | 1717 | a9e08234-c1be-4519-a3e3-dd8d9456fab0___RS_GLSp 7336_270deg.JPG         | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___healthy                             |
# | 1749 | e16bfc88-93b9-4036-b77f-614967a4ee2f___RS_GLSp 4652.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 1753 | e50fa094-ce6d-475b-91e7-55266a2677ac___RS_GLSp 4379 copy.jpg           | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 1773 | e28b1832-148d-45e5-9934-fc2e73d9db1e___NREC_B.Spot 9214_180deg.JPG     | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# | 1807 | 65a84ec0-79dc-4ae3-bfce-81c3f4b50a08___JR_B.Spot 8858_180deg.JPG       | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# | 1827 | ac6e6cad-2932-4af0-ad68-fdf044eecc8c___NREC_B.Spot 1796.JPG            | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___healthy                             |
# | 1841 | 78d28bb5-2b07-42eb-aff8-d205eaf38fc9___RS_NLB 3967_flipTB.JPG          | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 1850 | fa0d690b-b3ae-4ddd-b09d-ca8608233a1a___RS_GLSp 4629.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 1924 | RS_Rust 1745_flipLR.JPG                                                | Corn_(maize)___Common_rust_                        | Pepper,_bell___healthy                             |
# | 1930 | 66151c80-6947-4062-bbb0-3771e6feefc3___RS_GLSp 7304_270deg.JPG         | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___healthy                             |
# | 1948 | a3be7c5c-5a5c-4b66-87f9-d74a9d5d409d___RS_NLB 4228 copy_flipTB.jpg     | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 1960 | b73cddeb-5b44-404b-9ca5-6f5397f3d518___RS_GLSp 4400.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 1981 | e2faa2e3-433a-4ee3-9b64-8de4ad2947e1___RS_NLB 3795_flipTB.JPG          | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 2004 | bc690bb9-1611-4744-844d-0ab174467f54___RS_GLSp 4582.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 2072 | b81f901d-c870-43fd-b7c7-9b699d10d27e___JR_HL 8316.JPG                  | Pepper,_bell___healthy                             | Corn_(maize)___healthy                             |
# | 2084 | RS_Rust 2639_flipLR.JPG                                                | Corn_(maize)___Common_rust_                        | Pepper,_bell___healthy                             |
# | 2123 | 975b25df-a4d7-4aca-b1b9-312487544eaa___JR_B.Spot 8830.JPG              | Pepper,_bell___Bacterial_spot                      | Corn_(maize)___Northern_Leaf_Blight                |
# +------+------------------------------------------------------------------------+----------------------------------------------------+----------------------------------------------------+

# %%
# Extract the features using the trained CNN model
cnn_features = cnn_model.predict(X_train)
# Out:
# 281/281 [==============================] - 32s 115ms/step

# %% [markdown]
# # rf

# %%
import time

# %%
# import the Random Forest classifier
from RF_Manual import RandomForest

# %%
# Train a Random Forest classifier on the extracted features
start_time = time.time()
rf_classifier = RandomForest(n_trees=100, max_depth=42)
rf_classifier.fit(cnn_features, np.argmax(y_train, axis=1))

# count time for training
end_time = time.time()
training_time = end_time - start_time
print(f"Training time: {training_time} seconds")
# Out:
# Training time: 379.7937002182007 seconds

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Evaluate the performance of the Random Forest classifier on the test set
rf_features = cnn_model.predict(X_test)
rf_features = rf_features.reshape(rf_features.shape[0], -1)
rf_predictions = rf_classifier.predict(rf_features)
rf_accuracy = np.mean(rf_predictions == np.argmax(y_test, axis=1))
print("Random Forest Classifier Accuracy: %.2f%%" % (rf_accuracy * 100))

# Calculate and print the Precision
rf_precision = precision_score(np.argmax(y_test, axis=1), rf_predictions, average='weighted')
print("Random Forest Classifier Precision: %.2f" % rf_precision)

# Calculate and print the Recall
rf_recall = recall_score(np.argmax(y_test, axis=1), rf_predictions, average='weighted')
print("Random Forest Classifier Recall: %.2f" % rf_recall)

# Calculate and print the F1 score
rf_f1_score = f1_score(np.argmax(y_test, axis=1), rf_predictions, average='weighted')
print("Random Forest Classifier F1 Score: %.2f" % rf_f1_score)
# Out:
# 71/71 [==============================] - 13s 175ms/step
# Random Forest Classifier Accuracy: 97.91%
# Random Forest Classifier Precision: 0.98
# Random Forest Classifier Recall: 0.98
# Random Forest Classifier F1 Score: 0.98

# %%
# Create a DataFrame with true labels and predicted labels
df_rf = pd.DataFrame({'Filename': filename_test,
                      'True Labels': [target_labels[label] for label in y_test_classes],
                      'Predicted Labels': [target_labels[label] for label in rf_predictions]})

# Convert DataFrame to tabular format
table_rf = tabulate(df_rf, headers='keys', tablefmt='psql')

# Print the table
print(table_rf)

# Save the DataFrame to a CSV file
df_rf.to_csv('labels_predictions-rf-jagung+pepper.csv', index=False)
# Out:
# +------+-------------------------------------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# |      | Filename                                                                      | True Labels                                        | Predicted Labels                                   |
# |------+-------------------------------------------------------------------------------+----------------------------------------------------+----------------------------------------------------|
# |    0 | 98327d43-c692-4922-82e3-a4e0db73ae40___JR_HL 8483.JPG                         | Pepper,_bell___healthy                             | Pepper,_bell___healthy                             |
# |    1 | RS_Rust 2762.JPG                                                              | Corn_(maize)___Common_rust_                        | Corn_(maize)___Common_rust_                        |
# |    2 | 348aafc3-4309-4507-b6b3-cb037711ca48___RS_GLSp 4399_90deg.JPG                 | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# |    3 | bd2ca97a-465c-4f10-a561-8b0cbdb77db3___JR_HL 8897.JPG                         | Pepper,_bell___healthy                             | Pepper,_bell___healthy                             |
# |    4 | 852e8e42-c48b-4a49-9f06-cae0ecb7747e___R.S_HL 8271 copy.jpg                   | Corn_(maize)___healthy                             | Corn_(maize)___healthy                             |
# |    5 | 7f07dc8d-dc42-4b4a-89a8-f2d2e10bdba7___NREC_B.Spot 9167.JPG                   | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___Bacterial_spot                      |
# |    6 | d95f6c9c-1c62-47d6-a643-093cd3402162___RS_NLB 3942 copy 2_flipTB.jpg          | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Northern_Leaf_Blight                |
# |    7 | 429213c9-31f8-49e0-bf27-5ffe7c43100d___RS_NLB 0802_180deg.JPG                 | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Northern_Leaf_Blight                |
# |    8 | 1fdbead6-97f6-4712-8c5e-2a1285e1e777___JR_HL 8681_flipTB.JPG                  | Pepper,_bell___healthy                             | Pepper,_bell___healthy                             |
# |    9 | RS_Rust 2476.JPG                                                              | Corn_(maize)___Common_rust_                        | Corn_(maize)___Common_rust_                        |
# |   10 | 714f6741-cb60-432b-91f9-ebd5a8a7ded4___RS_GLSp 7325.JPG                       | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# |   11 | c0d0dfd0-2167-4cde-b90e-170703d962f0___RS_NLB 4255_flipTB.JPG                 | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Northern_Leaf_Blight                |
# |   12 | 7b3f4992-f771-4b6e-b25f-7ec4c5823c88___JR_B.Spot 8951.JPG                     | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___Bacterial_spot                      |
# |
Pepper,_bell___Bacterial_spot                      | Pepper,_bell___Bacterial_spot                      |
# | 2209 | 5f95cd89-5dfd-4b90-8f3a-7aa5a18020fa___JR_HL 8006.JPG                         | Pepper,_bell___healthy                             | Pepper,_bell___healthy                             |
# | 2210 | cdbba6b5-85c8-420c-af58-f5885809f9a3___JR_HL 8192.JPG                         | Pepper,_bell___healthy                             | Pepper,_bell___healthy                             |
# | 2211 | 3ba0eff1-bb0f-4624-8693-1890087db1d3___JR_HL 8510_180deg.JPG                  | Pepper,_bell___healthy                             | Pepper,_bell___healthy                             |
# | 2212 | cafa778c-9b8b-45e7-8ffe-bc6fb3eec439___NREC_B.Spot 1923_flipTB.JPG            | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___Bacterial_spot                      |
# | 2213 | ca005f55-ec22-41ef-b162-66724347da83___R.S_HL 5518 copy_flipLR.jpg            | Corn_(maize)___healthy                             | Corn_(maize)___healthy                             |
# | 2214 | 2a5d32e1-5b7f-4fc0-8078-87fd4de96375___RS_NLB 0794.JPG                        | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Northern_Leaf_Blight                |
# | 2215 | 763f79d6-2b20-479c-9237-8b69c60482fe___JR_HL 5968.JPG                         | Pepper,_bell___healthy                             | Pepper,_bell___healthy                             |
# | 2216 | e15e053c-4b0a-48a3-a622-c2395bd93b64___RS_NLB 4008_180deg.JPG                 | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Northern_Leaf_Blight                |
# | 2217 | e2bc1ccf-bbc2-457b-89cb-6e7154ec3414___NREC_B.Spot 9092_flipTB.JPG            | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___Bacterial_spot                      |
# | 2218 | 1e6e9501-4510-4950-abea-36882683aa5c___JR_HL 8435.JPG                         | Pepper,_bell___healthy                             | Pepper,_bell___healthy                             |
# | 2219 | 1aaaa11e-ec45-4d6d-ab7f-1d3ea053d14d___JR_HL 5937.JPG                         | Pepper,_bell___healthy                             | Pepper,_bell___healthy                             |
# | 2220 | ed668b2e-9249-4905-b5ea-9ef6bb4417dd___NREC_B.Spot 1974_180deg.JPG            | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___Bacterial_spot                      |
# | 2221 | RS_Rust 2676_flipLR.JPG                                                       | Corn_(maize)___Common_rust_                        | Corn_(maize)___Common_rust_                        |
# | 2222 | b7ec200a-5db5-479e-99d0-c40009123835___JR_B.Spot 3128_180deg.JPG              | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___Bacterial_spot                      |
# | 2223 | RS_Rust 2422_flipLR.JPG                                                       | Corn_(maize)___Common_rust_                        | Corn_(maize)___Common_rust_                        |
# | 2224 | d63f0a92-e489-4acd-b5df-847a83172abc___RS_GLSp 4607_270deg.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 2225 | 1219f26f-a23a-4c2a-99f0-407fc785c74a___JR_B.Spot 3332_180deg.JPG              | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___Bacterial_spot                      |
# | 2226 | 88bb3bc0-d78d-4446-8a5e-e050c3a60e14___R.S_HL 7888 copy_flipLR.jpg            | Corn_(maize)___healthy                             | Corn_(maize)___healthy                             |
# | 2227 | bebf32c0-2daa-484c-804b-a6552f30d58d___R.S_HL 5532 copy 2.jpg                 | Corn_(maize)___healthy                             | Corn_(maize)___healthy                             |
# | 2228 | 539b8a7d-f257-49ff-81b8-76f39b5ac752___NREC_B.Spot 1805_flipTB.JPG            | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___Bacterial_spot                      |
# | 2229 | 2251b665-207d-4500-a396-bc9bb097c34b___R.S_HL 8073 copy_flipLR.jpg            | Corn_(maize)___healthy                             | Corn_(maize)___healthy                             |
# | 2230 | 99df36d6-159e-45e7-81a3-b706b69e4171___JR_HL 8500.JPG                         | Pepper,_bell___healthy                             | Pepper,_bell___healthy                             |
# | 2231 | 254d1f23-8a22-4f21-9d5e-0c66733f102f___R.S_HL 8083 copy.jpg                   | Corn_(maize)___healthy                             | Corn_(maize)___healthy                             |
# | 2232 | c91abd9b-94e4-401a-893d-a93956048f54___JR_B.Spot 3124_180deg.JPG              | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___Bacterial_spot                      |
# | 2233 | a41e31a6-c07f-43d0-8b62-c7aae76262e6___RS_NLB 3951.JPG                        | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Northern_Leaf_Blight                |
# | 2234 | 3bc19f2c-2ab4-4a1c-bd0f-e0a322058b8b___RS_GLSp 4423_new30degFlipLR.JPG        | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 2235 | db57594f-4114-4312-a817-7f5fe70ac5ca___JR_HL 8066.JPG                         | Pepper,_bell___healthy                             | Pepper,_bell___healthy                             |
# | 2236 | RS_Rust 2050_flipLR.JPG                                                       | Corn_(maize)___Common_rust_                        | Corn_(maize)___Common_rust_                        |
# | 2237 | c3b2554c-1408-445d-8f08-fae1b240b930___JR_HL 5956.JPG                         | Pepper,_bell___healthy                             | Pepper,_bell___healthy                             |
# | 2238 | 6fc860ea-46cd-4b40-8d53-27c1ebf95935___NREC_B.Spot 1836.JPG                   | Pepper,_bell___Bacterial_spot                      | Pepper,_bell___Bacterial_spot                      |
# | 2239 | 79aa374c-1687-42d4-bf48-84e8b1beb762___RS_GLSp 4408_new30degFlipLR.JPG        | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 2240 | 751475e8-516b-4708-8509-7137931ad7ae___RS_NLB 3597_flipTB.JPG                 | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Northern_Leaf_Blight                |
# | 2241 | 97173da1-f3d9-4b42-8e86-3f2a066c1704___RS_GLSp 4449_270deg.JPG                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 2242 | d4bf70c0-f7fe-4921-9944-a89717811183___RS_GLSp 4373.JPG                       | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 2243 | 22177231-7c14-423d-a83c-78a63c2dfd9a___RS_GLSp 9286.JPG                       | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# +------+-------------------------------------------------------------------------------+----------------------------------------------------+----------------------------------------------------+

# %%
# Filter rows where true label and predicted label do not match
false_predictions_rf = df_rf[df_rf['True Labels'] != df_rf['Predicted Labels']]

# Convert DataFrame to tabular format
table_rf = tabulate(false_predictions_rf, headers='keys', tablefmt='psql')

# Print the false predictions table
print("False Predictions:")
print(table_rf)

# Save the false predictions to a CSV file
false_predictions_rf.to_csv('false_predictions-rf-jagung+pepper.csv', index=False)
# Out:
# False Predictions:
# +------+--------------------------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# |      | Filename                                                           | True Labels                                        | Predicted Labels                                   |
# |------+--------------------------------------------------------------------+----------------------------------------------------+----------------------------------------------------|
# |   93 | a401fce7-28ad-4d2f-bf98-3ef87ae65ba5___RS_GLSp 4614.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  202 | bbea95f8-cc26-40b6-9436-228f70d605d7___RS_GLSp 7332.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  210 | f5eb9c66-7174-4f62-8261-7c7520601824___RS_GLSp 9342.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Common_rust_                        |
# |  279 | 6728afe3-9ab4-4235-b7e3-5b9ee80b6675___RS_NLB 3605_flipTB.JPG      | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# |  281 | 629273b6-9eaa-4084-b72b-ac856a9ef899___RS_GLSp 4636_270deg.JPG     | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  291 | 34ae03ee-4314-47b1-a568-f3537bc2afba___RS_NLB 3672_180deg.JPG      | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# |  301 | 74967cb3-e984-43f3-9bd3-74ba302b1db7___RS_GLSp 4555.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  305 | bbde9366-ec3c-4354-815b-5b95b6cdb676___RS_GLSp 4481.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  320 | 1157b4eb-dfb3-41b7-a083-77b0ca2e7634___RS_GLSp 4460.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  395 | b2980d13-da6a-4475-bb60-abed664c5506___RS_GLSp 4678.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  431 | baf87bb4-cf33-432d-ae8c-6ee3bd6dacce___JR_B.Spot 8988_flipTB.JPG   | Pepper,_bell___Bacterial_spot                      | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# |  577 | 6089948d-346f-4745-af12-4355a7ef3dea___RS_NLB 3800_flipTB.JPG      | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# |  605 | ba462265-a5c8-4fa8-abb4-24054691eb16___RS_GLSp 3809.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  694 | 910679a5-f18d-40ac-a00e-9e2c27a45610___RS_GLSp 9327.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  740 | 6e2464e9-1034-4ee9-9211-63e57ad09031___RS_GLSp 4661_90deg.JPG      | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  770 | 3aeb9908-679b-4d53-8925-5b436d0961d8___RS_GLSp 9317.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# |  825 | 03a4f6f6-9c17-4310-921b-5dbf97df630a___JR_HL 8571_newPixel25.JPG   | Pepper,_bell___healthy                             | Corn_(maize)___healthy                             |
# |  863 | 4baea4d9-8343-4550-838f-86dfb7672591___RS_GLSp 4639 copy.jpg       | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 1018 | e22976d4-ff48-4672-ad70-e17d50b65b1c___RS_NLB 3688_180deg.JPG      | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 1024 | 057c3f91-c15e-464b-b4ba-66b16dbe5149___RS_NLB 3565 copy.jpg        | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 1083 | 44209d86-9fed-42cd-b5dc-5580166b10ab___RS_GLSp 4684.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 1132 | 98d0dbe1-2532-419e-9cc4-1ef0da68fb0e___RS_GLSp 4452.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 1155 | d2a1f0d8-2835-4984-80fd-11be9e18ab22___RS_GLSp 4580.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 1195 | d3d7a5a3-ee3f-4654-8e90-8e722d433972___RS_NLB 3553_180deg.JPG      | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Common_rust_                        |
# | 1212 | RS_Rust 2655_flipLR.JPG                                            | Corn_(maize)___Common_rust_                        | Pepper,_bell___Bacterial_spot                      |
# | 1256 | 68a8b022-1f2d-4546-957f-a69aa11f0e39___JR_HL 8122.JPG              | Pepper,_bell___healthy                             | Pepper,_bell___Bacterial_spot                      |
# | 1270 | 573ad2a6-906a-4d32-af81-0026fc57258f___RS_GLSp 4613.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 1291 | 50a8d45e-07fa-495d-8779-e07715b1c644___RS_GLSp 9358.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Common_rust_                        |
# | 1548 | RS_Rust 1680_flipLR.JPG                                            | Corn_(maize)___Common_rust_                        | Pepper,_bell___Bacterial_spot                      |
# | 1555 | 2e594c45-c4c7-43b1-ab19-100945e7a2a7___RS_NLB 4020 copy 3.jpg      | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 1638 | 15803dee-8071-49f1-81b6-fd3dedbc1c58___RS_NLB 4020 copy.jpg        | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 1639 | 5dc9613c-fcbf-42ce-a95a-6520bf780872___RS_NLB 4225.JPG             | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 1717 | a9e08234-c1be-4519-a3e3-dd8d9456fab0___RS_GLSp 7336_270deg.JPG     | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___healthy                             |
# | 1749 | e16bfc88-93b9-4036-b77f-614967a4ee2f___RS_GLSp 4652.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 1753 | e50fa094-ce6d-475b-91e7-55266a2677ac___RS_GLSp 4379 copy.jpg       | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 1776 | 7ff116fc-5095-4377-bcf1-b173f05c9e7b___RS_GLSp 7323.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 1841 | 78d28bb5-2b07-42eb-aff8-d205eaf38fc9___RS_NLB 3967_flipTB.JPG      | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 1850 | fa0d690b-b3ae-4ddd-b09d-ca8608233a1a___RS_GLSp 4629.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 1942 | 59726309-40b6-498d-a487-ff2d8fc455a8___RS_GLSp 4686.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 1948 | a3be7c5c-5a5c-4b66-87f9-d74a9d5d409d___RS_NLB 4228 copy_flipTB.jpg | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 1960 | b73cddeb-5b44-404b-9ca5-6f5397f3d518___RS_GLSp 4400.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 1981 | e2faa2e3-433a-4ee3-9b64-8de4ad2947e1___RS_NLB 3795_flipTB.JPG      | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# | 2004 | bc690bb9-1611-4744-844d-0ab174467f54___RS_GLSp 4582.JPG            | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 2072 | b81f901d-c870-43fd-b7c7-9b699d10d27e___JR_HL 8316.JPG              | Pepper,_bell___healthy                             | Corn_(maize)___healthy                             |
# | 2118 | b9a39437-94b7-41e3-b309-080e9a93d5ca___RS_GLSp 4440_90deg.JPG      | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot | Corn_(maize)___Northern_Leaf_Blight                |
# | 2123 | 975b25df-a4d7-4aca-b1b9-312487544eaa___JR_B.Spot 8830.JPG          | Pepper,_bell___Bacterial_spot                      | Corn_(maize)___Northern_Leaf_Blight                |
# | 2147 | 057c3f91-c15e-464b-b4ba-66b16dbe5149___RS_NLB 3565 copy_flipTB.jpg | Corn_(maize)___Northern_Leaf_Blight                | Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot |
# +------+--------------------------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
